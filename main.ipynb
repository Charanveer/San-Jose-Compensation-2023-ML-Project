# %%
#Import Libraries
import pandas as pd
import numpy as np

# %%
#Load Dataset
data = pd.read_csv('data.csv')
data.head()
# Out:
#                  Name Department Job Title (as of 12/31/23)  \
# 0  Maximillian Duenas       Fire               Fire Captain
# 1    Galvin Charekian       Fire               Fire Captain
# 2            Ali Miri     Police          Police Lieutenant
# 3         Martin Mora       Fire              Fire Engineer
# 4      Spencer Piercy       Fire              Fire Engineer
#
#   Total Cash Compensation    Base Pay    Overtime Sick and Vacation Payouts  \
# 0              620,986.55  180,574.29  436,373.06                       NaN
# 1              505,127.13  180,574.29  309,358.34                       NaN
# 2              457,417.50  201,148.00  218,841.40                       NaN
# 3              453,006.39  157,370.85  291,596.34                       NaN
# 4              446,067.98  157,370.85  287,852.25                       NaN
#
#   Other Cash Compensation Defined Contribution Plan Contributions - City Paid  \
# ...

# %%
data.isnull().any()
# Out:
# Name                                                   False
# Department                                             False
# Job Title (as of 12/31/23)                             False
# Total Cash Compensation                                False
# Base Pay                                                True
# Overtime                                                True
# Sick and Vacation Payouts                               True
# Other Cash Compensation                                 True
# Defined Contribution Plan Contributions - City Paid     True
# Medical Dental Vision                                   True
# Retirement Contributions (Normal Cost) - City Paid      True
# Long Term Disability, Life, Medicare                    True
# Misc Employment Related Costs                           True
# dtype: bool

# %%
data = data.drop(columns=['Defined Contribution Plan Contributions - City Paid',
                   'Medical Dental Vision',
                   'Retirement Contributions (Normal Cost) - City Paid',
                   'Long Term Disability, Life, Medicare',
                   'Misc Employment Related Costs'])

# %%
# Handle missing values
data.fillna(0, inplace=True)
data
# Out:
#                     Name                      Department  \
# 0     Maximillian Duenas                            Fire
# 1       Galvin Charekian                            Fire
# 2               Ali Miri                          Police
# 3            Martin Mora                            Fire
# 4         Spencer Piercy                            Fire
# ...                  ...                             ...
# 8641       Sammy Aguirre          Environmental Services
# 8642      Jazmin Delgado                    Public Works
# 8643        Marissa Boyd  Parks/Rec & Neigh Serv P R N S
# 8644       Adriana Imbre          Environmental Services
# 8645    Roman Bodnarchuk                            Fire
#
#       Job Title (as of 12/31/23) Total Cash Compensation    Base Pay  \
# 0                   Fire Captain              620,986.55  180,574.29
# 1                   Fire Captain              505,127.13  180,574.29
# 2              Police Lieutenant              457,417.50  201,148.00
# ...

# %%
# Separate features and target
X = data.drop(columns=['Total Cash Compensation', 'Name'])
y = data['Total Cash Compensation']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Remove commas from numerical columns and convert to float
numerical_columns = [

'Name',	'Department'	,'Job Title (as of 12/31/23)',	'Total Cash Compensation'	,'Base Pay'	,'Overtime'
	,'Sick and Vacation Payouts'	,'Other Cash Compensation'

]

for col in numerical_columns:
    data[col] = data[col].astype(str).str.replace(',', '').astype(float)

# Separate features and target
X = data.drop(columns=['Total Cash Compensation', 'Name'])
y = data['Total Cash Compensation']

# Identify categorical and numerical features
categorical_features = ['Department', 'Job Title (as of 12/31/23)']
numerical_features = X.select_dtypes(include=[np.number]).columns.tolist()

# One-hot encode categorical features
encoder = OneHotEncoder(handle_unknown='ignore')
X_encoded = encoder.fit_transform(X[categorical_features]).toarray()

# Convert encoded features to DataFrame
encoded_df = pd.DataFrame(X_encoded, columns=encoder.get_feature_names_out(categorical_features))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 10
#       2 numerical_columns = [
#       3
#       4 'Name',	'Department'	,'Job Title (as of 12/31/23)',	'Total Cash Compensation'	,'Base Pay'	,'Overtime'
#       5 	,'Sick and Vacation Payouts'	,'Other Cash Compensation'
#       6
#       7 ]
#       9 for col in numerical_columns:
# ---> 10     data[col] = data[col].astype(str).str.replace(',', '').astype(float)
#      12 # Separate features and target
#      13 X = data.drop(columns=['Total Cash Compensation', 'Name'])
#
# File c:\Users\Charanveer Singh\scoop\apps\python\current\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
# ...
